# %% [markdown]
# **utiles**

# %%
from datetime import datetime
import numpy as np
import time,os,json,glob,shutil

def log(text):
    text=str(text)
    dt=datetime.now()
    logText=dt.strftime(" [%Y-%m-%d %H:%M:%S]: ")+text
    with open('log.txt','a+',encoding="utf-8") as f:
        f.write(logText+"\n")
    print(logText)

def readTxt(file):
    with open(file,'r',encoding="utf-8") as f:
        return f.read()

def toArray(list):
    return np.array(list)

def threeSequecne(text,num):
    t_list=[]
    for i in range(len(text)-num+1):
        t_list.append(text[i:i+num])
    return " ".join(t_list)

def threeSequecneCnn(text):
    t_list=[]
    for i in range(len(text)-1):
        t_list.append(text[i:i+2])
    return toArray(t_list)


def anySequecne(text,value):
    t_list=[]
    for i in range(len(text)-(value-1)):
        t_list.append(text[i:i+value])
    return " ".join(t_list)

# %% [markdown]
# **benchmark identifier**

# %%
from random import shuffle
from turtle import shape
from numpy import dtype
import tensorflow as tf
from sklearn.model_selection import KFold
import sys
sys.path.append('.')

# %%
def readTxt(file):
    with open(file,'r',encoding="utf-8") as f:
        return f.read().split("\n")

dic={'A':'A','T':'T','G':'G','C':'C'}
dic_con={'A':1,'T':2,'G':3,'C':4}
def readTxt(file):
    with open(file,'r',encoding="utf-8") as f:
        return f.read().split("\n")

# %%
non_test=readTxt("/content/drive/MyDrive/iEnhancer-DLRA/dataset/non_test.txt")
non_train=readTxt("/content/drive/MyDrive/iEnhancer-DLRA/dataset/non_train.txt")
strong_test=readTxt("/content/drive/MyDrive/iEnhancer-DLRA/dataset/strong_test.txt")
strong_train=readTxt("/content/drive/MyDrive/iEnhancer-DLRA/dataset/strong_train.txt")
weak_test=readTxt("/content/drive/MyDrive/iEnhancer-DLRA/dataset/weak_test.txt")
weak_train=readTxt("/content/drive/MyDrive/iEnhancer-DLRA/dataset/weak_train.txt")

# %%
def GenerateFromTextToNumpy(label,train):
    train_con=[]
    train_text=[]
    train_text_5=[]
    train_y=[]
    for i in train:

        con_t=[dic_con[key] for key in i]
        train_con.append(np.array(con_t))

        t=threeSequecne(i,4)
        train_text.append(np.array(t))

        t=threeSequecne(i,7)
        train_text_5.append(np.array(t))

        train_y.append(np.array([label]))
    train_con=np.array(train_con)
    train_text_5=np.array(train_text_5)
    train_text=np.array(train_text)
    train_y=np.array(train_y)
    return (train_con,train_text,train_y,train_text_5)

# %%
def GenerateLayerOneTestData():
    non_test_data=GenerateFromTextToNumpy(0,non_test)
    strong_test_data=GenerateFromTextToNumpy(1,strong_test)
    weak_test_data=GenerateFromTextToNumpy(1,weak_test)
    test_x={"con":np.concatenate((non_test_data[0],strong_test_data[0],weak_test_data[0]))[:,:,np.newaxis],"text":np.concatenate((non_test_data[1],strong_test_data[1],weak_test_data[1])),"text_5":np.concatenate((non_test_data[3],strong_test_data[3],weak_test_data[3]))}
    test_y=np.concatenate((non_test_data[2],strong_test_data[2],weak_test_data[2]))
    return test_x,test_y

# %%
def returnAccuracy():
    import math
    TP=self_evaluate(po_test,test_y[0:200])
    TN=self_evaluate(ne_test,test_y[200:])
    FP=1-TN
    FN=1-TP
    SN=TP/(TP+FN)
    SP=TN/(TN+FP)
    ACC=(TP+TN)/(TP+TN+FN+FP)
    try:
        MCC=(TP*TN-FP*FN)/math.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
    except:
        MCC=-1
    text={"ACC":ACC,"SP":SP,"SN":SN,"MCC":MCC}
    return text

# %%
def self_evaluate(x,y):
    res=tf.nn.sigmoid(model.predict(x))
    res=np.array(res)
    res[res>=0.5]=1
    res[res<0.5]=0
    sum=0
    correct=0
    for i,j in zip(res,y):
        sum+=1
        if i==j:
            correct+=1
    return correct/sum

# %%
non_train_data=GenerateFromTextToNumpy(0,non_train)
strong_train_data=GenerateFromTextToNumpy(1,strong_train)
weak_train_data=GenerateFromTextToNumpy(1,weak_train)

train_text=np.concatenate((non_train_data[1],strong_train_data[1],weak_train_data[1]))
train_con=np.concatenate((non_train_data[0],strong_train_data[0],weak_train_data[0]))[:,:,np.newaxis]
train_text_5=np.concatenate((non_train_data[3],strong_train_data[3],weak_train_data[3]))

train_y=np.concatenate((non_train_data[2],strong_train_data[2],weak_train_data[2]))
test_x,test_y=GenerateLayerOneTestData()

po_test=test_x.copy()
po_test["con"]=po_test["con"][0:200]
po_test["text"]=po_test["text"][0:200]
po_test["text_5"]=po_test["text"][0:200]
ne_test=test_x.copy()
ne_test["con"]=ne_test["con"][200:]
ne_test["text"]=ne_test["text"][200:]
ne_test["text_5"]=ne_test["text_5"][200:]


kf=KFold(n_splits=10,shuffle=True,random_state=5)
t=kf.split(train_text)
index_list=[(i[0],i[1]) for i in t]

# %%
def load_model():
        global encoder
        kernel_num=256
        kernel_size_1=1
        kernel_size_2=2
        kernel_size_3=3
        input_con=tf.keras.Input(shape=(200,1),name='con')
        y=tf.keras.layers.Conv1D(kernel_num,kernel_size=kernel_size_1,strides=1,padding='same', activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.l2(0.01))(input_con)
        y=tf.keras.layers.Conv1D(kernel_num, kernel_size=kernel_size_1,strides=1, padding='same', activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.l2(0.01))(y)

        block1_output=tf.keras.layers.BatchNormalization()(y)

        y=tf.keras.layers.Conv1D(kernel_num, kernel_size=kernel_size_2,strides=1, padding='same', activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.l2(0.01))(block1_output)
        y=tf.keras.layers.Conv1D(kernel_num, kernel_size=kernel_size_2,strides=1, padding='same', activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.l2(0.01))(y)

        y=tf.keras.layers.BatchNormalization()(y)

        block2_output=tf.keras.layers.add([y,block1_output])

        y=tf.keras.layers.Conv1D(kernel_num, kernel_size=kernel_size_3, padding='same', activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.l2(0.01))(block2_output)
        y=tf.keras.layers.Conv1D(kernel_num, kernel_size=kernel_size_3, padding='same', activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.l2(0.01))(y)
        y=tf.keras.layers.BatchNormalization()(y)

        block3_output=tf.keras.layers.add([y,block2_output])


        y=tf.keras.layers.Conv1D(kernel_num, kernel_size=3, padding='same', activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.l2(0.01))(block3_output)

        y=tf.keras.layers.GlobalAveragePooling1D()(y)
        y=tf.keras.layers.Dense(256,activation='relu')(y)

        input_text=tf.keras.Input(shape=(1,),dtype='string',name="text")
        encoder=tf.keras.layers.TextVectorization(max_tokens=100)
        encoder.adapt(train_text)
        x=encoder(input_text)

        x=tf.keras.layers.Embedding(input_dim=len(encoder.get_vocabulary()),output_dim=64,mask_zero=True)(x)
        x=tf.keras.layers.Attention(name="ATT12")([x,x])
        x=tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,return_sequences=True,name="LSTM12"),name="B11")(x)
        x=tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,name="LSTM21"),name="B12")(x)
        x=tf.keras.layers.Dense(512,activation='relu')(x)

        input_text_5=tf.keras.Input(shape=(1,),dtype='string',name="text_5")
        encoder_5=tf.keras.layers.TextVectorization(max_tokens=100)
        encoder_5.adapt(train_text_5)
        z=encoder_5(input_text_5)

        z=tf.keras.layers.Embedding(input_dim=len(encoder.get_vocabulary()),output_dim=64,mask_zero=True)(z)
        z=tf.keras.layers.Attention(name="ATT1")([z,z])
        z=tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,return_sequences=True,name="LSTM1"),name="B1")(z)
        z=tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,name="LSTM2"),name="B2")(z)
        z=tf.keras.layers.Dense(512,activation='relu')(z)

        x=tf.keras.layers.add([z,x])

        feature_layer=tf.keras.layers.concatenate([x,y])

        att=tf.keras.layers.Attention()([feature_layer,feature_layer,feature_layer])

        d=tf.keras.layers.Dense(768,activation='relu')(att)
        d=tf.keras.layers.Dropout(0.1)(d)
        output=tf.keras.layers.Dense(1)(d)
        model=tf.keras.Model([input_text_5,input_text,input_con],output)
        base_learning_rate = 0.001
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),metrics=['accuracy'])
        return model

# %%
def train(index):
    epochs=120
    TRAIN_ACC=0
    MAX_ACC=0
    loss=100
    text={}
    val_acc=0
    for i in range(epochs):
        if i<30:
            lr=0.001
        elif i<80:
            lr=0.0005
        else:
            lr=0.0001
        def scheduler(epoch):
            return lr
        reduce_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
        print(f"index:{index},epochs:{i}")
        history=model.fit(each_fold_train_x,each_fold_train_y,verbose = 0,shuffle=True,epochs=1,validation_data=(each_fold_val_x,each_fold_val_y),batch_size=128,callbacks=[reduce_lr])
        train_acc=self_evaluate(each_fold_train_x,each_fold_train_y)
        log_info=history.history
        val_acc=self_evaluate(each_fold_val_x,each_fold_val_y)
        log_info['val_accuracy']=[val_acc]
        log_info['accuracy']=[train_acc]
        print("Training:")
        print(log_info)
        if history.history["val_loss"][0]<loss:
            loss=history.history["val_loss"][0]
            text=returnAccuracy()
            text["val_acc"]=val_acc
            print("UpdateTest:")
            print(text)


    record.append(text)

# %%
def printFinalResult():
    ACC=0
    SP=0
    SN=0
    MCC=0
    VAL_ACC=0
    for i in record:
        ACC+=i["ACC"]
        SP+=i["SP"]
        SN+=i["SN"]
        MCC+=i["MCC"]

    ACC/=10
    SP/=10
    SN/=10
    MCC/=10
    VAL_ACC/=10
    text={"ACC":ACC,"SP":SP,"SN":SN,"MCC":MCC,"VAL_ACC":VAL_ACC}
    print(text)

# %%
if __name__=="__main__":
    record=[]
    for fold in range(0,10):
        fold_order=fold
        (train_index,val_index)=index_list[fold_order]
        each_fold_train_x={"con":train_con[train_index],"text":train_text[train_index],"text_5":train_text_5[train_index]}
        each_fold_train_y=train_y[train_index]
        each_fold_val_x={"con":train_con[val_index],"text":train_text[val_index],"text_5":train_text_5[val_index]}
        each_fold_val_y=train_y[val_index]
        model=load_model()
        train(fold)
    printFinalResult()
# Out:
# index:0,epochs:0
# 84/84 [==============================] - 13s 35ms/step
# 10/10 [==============================] - 0s 43ms/step
# Training:
# {'loss': [13.066902160644531], 'accuracy': [0.4979408461250468], 'val_loss': [10.152308464050293], 'val_accuracy': [0.5185185185185185], 'lr': [0.001]}
# 7/7 [==============================] - 0s 50ms/step
# 7/7 [==============================] - 0s 30ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.5185185185185185}
# index:0,epochs:1
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 30ms/step
# Training:
# {'loss': [7.997749328613281], 'accuracy': [0.4979408461250468], 'val_loss': [6.164769172668457], 'val_accuracy': [0.5185185185185185], 'lr': [0.001]}
# 7/7 [==============================] - 0s 29ms/step
# 7/7 [==============================] - 0s 30ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.5185185185185185}
# index:0,epochs:2
# 84/84 [==============================] - 3s 36ms/step
# 10/10 [==============================] - 0s 40ms/step
# Training:
# {'loss': [4.786105155944824], 'accuracy': [0.4979408461250468], 'val_loss': [3.807366132736206], 'val_accuracy': [0.5185185185185185], 'lr': [0.001]}
# 7/7 [==============================] - 0s 42ms/step
# 7/7 [==============================] - 0s 30ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.5185185185185185}
# index:0,epochs:3
# 84/84 [==============================] - 3s 30ms/step
# 10/10 [==============================] - 0s 30ms/step
# Training:
# {'loss': [2.951467752456665], 'accuracy': [0.4979408461250468], 'val_loss': [2.4883811473846436], 'val_accuracy': [0.5185185185185185], 'lr': [0.001]}
# 7/7 [==============================] - 0s 30ms/step
# 7/7 [==============================] - 0s 29ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.5185185185185185}
# index:0,epochs:4
# 84/84 [==============================] - 3s 30ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [1.9636999368667603], 'accuracy': [0.4979408461250468], 'val_loss': [1.7710001468658447], 'val_accuracy': [0.5185185185185185], 'lr': [0.001]}
# 7/7 [==============================] - 0s 30ms/step
# 7/7 [==============================] - 0s 30ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.5185185185185185}
# index:0,epochs:5
# 84/84 [==============================] - 3s 38ms/step
# 10/10 [==============================] - 0s 29ms/step
# Training:
# {'loss': [1.4185761213302612], 'accuracy': [0.4979408461250468], 'val_loss': [1.3627368211746216], 'val_accuracy': [0.5185185185185185], 'lr': [0.001]}
# 7/7 [==============================] - 0s 29ms/step
# 7/7 [==============================] - 0s 30ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.5185185185185185}
# index:0,epochs:6
# 84/84 [==============================] - 3s 30ms/step
# 10/10 [==============================] - 0s 41ms/step
# Training:
# {'loss': [1.0892983675003052], 'accuracy': [0.4979408461250468], 'val_loss': [1.1270240545272827], 'val_accuracy': [0.5185185185185185], 'lr': [0.001]}
# 7/7 [==============================] - 0s 30ms/step
# 7/7 [==============================] - 0s 29ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.5185185185185185}
# index:0,epochs:7
# 84/84 [==============================] - 3s 30ms/step
# 10/10 [==============================] - 0s 29ms/step
# Training:
# {'loss': [0.8948737382888794], 'accuracy': [0.5020591538749531], 'val_loss': [0.9838517904281616], 'val_accuracy': [0.48148148148148145], 'lr': [0.001]}
# 7/7 [==============================] - 0s 32ms/step
# 7/7 [==============================] - 0s 43ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.48148148148148145}
# index:0,epochs:8
# 84/84 [==============================] - 3s 30ms/step
# 10/10 [==============================] - 0s 30ms/step
# Training:
# {'loss': [0.7824380993843079], 'accuracy': [0.5380007487832272], 'val_loss': [0.8868194222450256], 'val_accuracy': [0.5185185185185185], 'lr': [0.001]}
# 7/7 [==============================] - 0s 30ms/step
# 7/7 [==============================] - 0s 31ms/step
# UpdateTest:
# {'ACC': 0.58, 'SP': 1.0, 'SN': 0.16, 'MCC': 0.29488391230979427, 'val_acc': 0.5185185185185185}
# index:0,epochs:9
# 84/84 [==============================] - 3s 33ms/step
# 10/10 [==============================] - 0s 45ms/step
# Training:
# {'loss': [0.7153475284576416], 'accuracy': [0.4979408461250468], 'val_loss': [0.838334858417511], 'val_accuracy': [0.5185185185185185], 'lr': [0.001]}
# 7/7 [==============================] - 0s 29ms/step
# 7/7 [==============================] - 0s 30ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.5185185185185185}
# index:0,epochs:10
# 84/84 [==============================] - 3s 36ms/step
# 10/10 [==============================] - 0s 42ms/step
# Training:
# {'loss': [0.6570399403572083], 'accuracy': [0.4979408461250468], 'val_loss': [0.7992647290229797], 'val_accuracy': [0.5185185185185185], 'lr': [0.001]}
# 7/7 [==============================] - 0s 29ms/step
# 7/7 [==============================] - 0s 30ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.5185185185185185}
# index:0,epochs:11
# 84/84 [==============================] - 3s 41ms/step
# 10/10 [==============================] - 0s 30ms/step
# Training:
# {'loss': [0.645353376865387], 'accuracy': [0.5140396855110445], 'val_loss': [0.7752116918563843], 'val_accuracy': [0.48148148148148145], 'lr': [0.001]}
# 7/7 [==============================] - 0s 30ms/step
# 7/7 [==============================] - 0s 30ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.48148148148148145}
# index:0,epochs:12
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 41ms/step
# Training:
# {'loss': [0.6183391213417053], 'accuracy': [0.5020591538749531], 'val_loss': [0.7582859396934509], 'val_accuracy': [0.48148148148148145], 'lr': [0.001]}
# 7/7 [==============================] - 0s 30ms/step
# 7/7 [==============================] - 0s 29ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.48148148148148145}
# index:0,epochs:13
# 84/84 [==============================] - 3s 33ms/step
# 10/10 [==============================] - 0s 30ms/step
# Training:
# {'loss': [0.5982671976089478], 'accuracy': [0.9827779857731187], 'val_loss': [0.7094265222549438], 'val_accuracy': [0.9191919191919192], 'lr': [0.001]}
# 7/7 [==============================] - 0s 42ms/step
# 7/7 [==============================] - 0s 40ms/step
# UpdateTest:
# {'ACC': 1.0, 'SP': 1.0, 'SN': 1.0, 'MCC': 1.0, 'val_acc': 0.9191919191919192}
# index:0,epochs:14
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 30ms/step
# Training:
# {'loss': [0.5937177538871765], 'accuracy': [0.5020591538749531], 'val_loss': [0.7308884859085083], 'val_accuracy': [0.48148148148148145], 'lr': [0.001]}
# index:0,epochs:15
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 45ms/step
# Training:
# {'loss': [0.5729013681411743], 'accuracy': [0.5020591538749531], 'val_loss': [0.7372370362281799], 'val_accuracy': [0.48148148148148145], 'lr': [0.001]}
# index:0,epochs:16
# 84/84 [==============================] - 3s 37ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.5752872824668884], 'accuracy': [0.5020591538749531], 'val_loss': [0.7539420127868652], 'val_accuracy': [0.48148148148148145], 'lr': [0.001]}
# index:0,epochs:17
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 43ms/step
# Training:
# {'loss': [0.5865708589553833], 'accuracy': [0.5020591538749531], 'val_loss': [0.7371949553489685], 'val_accuracy': [0.48148148148148145], 'lr': [0.001]}
# index:0,epochs:18
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.5752142071723938], 'accuracy': [0.5054286783976039], 'val_loss': [0.7073016166687012], 'val_accuracy': [0.48148148148148145], 'lr': [0.001]}
# 7/7 [==============================] - 0s 31ms/step
# 7/7 [==============================] - 0s 30ms/step
# UpdateTest:
# {'ACC': 0.5025, 'SP': 0.005, 'SN': 1.0, 'MCC': 0.05006261743217588, 'val_acc': 0.48148148148148145}
# index:0,epochs:19
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.5629650354385376], 'accuracy': [0.5020591538749531], 'val_loss': [0.755850613117218], 'val_accuracy': [0.48148148148148145], 'lr': [0.001]}
# index:0,epochs:20
# 84/84 [==============================] - 3s 40ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [0.5656651258468628], 'accuracy': [0.5024335454885811], 'val_loss': [0.7190665006637573], 'val_accuracy': [0.48148148148148145], 'lr': [0.001]}
# index:0,epochs:21
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [0.5622045993804932], 'accuracy': [0.4979408461250468], 'val_loss': [0.7161514759063721], 'val_accuracy': [0.5185185185185185], 'lr': [0.001]}
# index:0,epochs:22
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 1s 49ms/step
# Training:
# {'loss': [0.5551670789718628], 'accuracy': [0.5024335454885811], 'val_loss': [0.8220005631446838], 'val_accuracy': [0.48148148148148145], 'lr': [0.001]}
# index:0,epochs:23
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 43ms/step
# Training:
# {'loss': [0.5584360361099243], 'accuracy': [0.5020591538749531], 'val_loss': [0.8445678353309631], 'val_accuracy': [0.48148148148148145], 'lr': [0.001]}
# index:0,epochs:24
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 45ms/step
# Training:
# {'loss': [0.5511733293533325], 'accuracy': [0.5016847622613253], 'val_loss': [0.9082854390144348], 'val_accuracy': [0.48148148148148145], 'lr': [0.001]}
# index:0,epochs:25
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.6313011050224304], 'accuracy': [0.4979408461250468], 'val_loss': [0.8975608348846436], 'val_accuracy': [0.5185185185185185], 'lr': [0.001]}
# index:0,epochs:26
# 84/84 [==============================] - 3s 37ms/step
# 10/10 [==============================] - 0s 43ms/step
# Training:
# {'loss': [0.5980464220046997], 'accuracy': [0.9674279296143766], 'val_loss': [0.6012575030326843], 'val_accuracy': [0.9158249158249159], 'lr': [0.001]}
# 7/7 [==============================] - 0s 31ms/step
# 7/7 [==============================] - 0s 30ms/step
# UpdateTest:
# {'ACC': 0.9875, 'SP': 1.0, 'SN': 0.975, 'MCC': 0.975304830396693, 'val_acc': 0.9158249158249159}
# index:0,epochs:27
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 39ms/step
# Training:
# {'loss': [0.5628151893615723], 'accuracy': [0.5020591538749531], 'val_loss': [0.9306003451347351], 'val_accuracy': [0.48148148148148145], 'lr': [0.001]}
# index:0,epochs:28
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.5616732835769653], 'accuracy': [0.4979408461250468], 'val_loss': [1.0058717727661133], 'val_accuracy': [0.5185185185185185], 'lr': [0.001]}
# index:0,epochs:29
# 84/84 [==============================] - 3s 35ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [0.5591809153556824], 'accuracy': [0.5020591538749531], 'val_loss': [1.0988330841064453], 'val_accuracy': [0.48148148148148145], 'lr': [0.001]}
# index:0,epochs:30
# 84/84 [==============================] - 3s 40ms/step
# 10/10 [==============================] - 0s 30ms/step
# Training:
# {'loss': [0.5398182272911072], 'accuracy': [0.5024335454885811], 'val_loss': [1.1483159065246582], 'val_accuracy': [0.48148148148148145], 'lr': [0.0005]}
# index:0,epochs:31
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 1s 48ms/step
# Training:
# {'loss': [0.5340820550918579], 'accuracy': [0.5402470984649944], 'val_loss': [0.7328136563301086], 'val_accuracy': [0.49158249158249157], 'lr': [0.0005]}
# index:0,epochs:32
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 43ms/step
# Training:
# {'loss': [0.5259038805961609], 'accuracy': [0.5814301759640584], 'val_loss': [0.679576575756073], 'val_accuracy': [0.531986531986532], 'lr': [0.0005]}
# index:0,epochs:33
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.5306787490844727], 'accuracy': [0.5043055035567203], 'val_loss': [0.8677569627761841], 'val_accuracy': [0.48148148148148145], 'lr': [0.0005]}
# index:0,epochs:34
# 84/84 [==============================] - 3s 40ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.5347064733505249], 'accuracy': [0.9191314114563833], 'val_loss': [0.5018914937973022], 'val_accuracy': [0.8787878787878788], 'lr': [0.0005]}
# 7/7 [==============================] - 0s 31ms/step
# 7/7 [==============================] - 0s 30ms/step
# UpdateTest:
# {'ACC': 0.9275, 'SP': 0.99, 'SN': 0.865, 'MCC': 0.861758998461038, 'val_acc': 0.8787878787878788}
# index:0,epochs:35
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 35ms/step
# Training:
# {'loss': [0.5270445346832275], 'accuracy': [0.6525645825533508], 'val_loss': [0.6168519258499146], 'val_accuracy': [0.6363636363636364], 'lr': [0.0005]}
# index:0,epochs:36
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.527574896812439], 'accuracy': [0.8581055784350431], 'val_loss': [0.471599280834198], 'val_accuracy': [0.8080808080808081], 'lr': [0.0005]}
# 7/7 [==============================] - 0s 31ms/step
# 7/7 [==============================] - 0s 31ms/step
# UpdateTest:
# {'ACC': 0.86, 'SP': 0.73, 'SN': 0.99, 'MCC': 0.74564371920144, 'val_acc': 0.8080808080808081}
# index:0,epochs:37
# 84/84 [==============================] - 3s 36ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.5195873379707336], 'accuracy': [0.6450767502807937], 'val_loss': [0.6710949540138245], 'val_accuracy': [0.622895622895623], 'lr': [0.0005]}
# index:0,epochs:38
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 42ms/step
# Training:
# {'loss': [0.5248562097549438], 'accuracy': [0.6525645825533508], 'val_loss': [0.6345301866531372], 'val_accuracy': [0.6430976430976431], 'lr': [0.0005]}
# index:0,epochs:39
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 43ms/step
# Training:
# {'loss': [0.523925244808197], 'accuracy': [0.5642081617371771], 'val_loss': [0.7910234332084656], 'val_accuracy': [0.5420875420875421], 'lr': [0.0005]}
# index:0,epochs:40
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 42ms/step
# Training:
# {'loss': [0.5293123722076416], 'accuracy': [0.592661924372894], 'val_loss': [0.7966781258583069], 'val_accuracy': [0.5488215488215489], 'lr': [0.0005]}
# index:0,epochs:41
# 84/84 [==============================] - 3s 36ms/step
# 10/10 [==============================] - 0s 43ms/step
# Training:
# {'loss': [0.5320510864257812], 'accuracy': [0.6630475477349307], 'val_loss': [0.7047598361968994], 'val_accuracy': [0.6026936026936027], 'lr': [0.0005]}
# index:0,epochs:42
# 84/84 [==============================] - 3s 40ms/step
# 10/10 [==============================] - 0s 40ms/step
# Training:
# {'loss': [0.5253714919090271], 'accuracy': [0.9314863347061025], 'val_loss': [0.39984121918678284], 'val_accuracy': [0.8922558922558923], 'lr': [0.0005]}
# 7/7 [==============================] - 0s 30ms/step
# 7/7 [==============================] - 0s 31ms/step
# UpdateTest:
# {'ACC': 0.9225, 'SP': 0.89, 'SN': 0.955, 'MCC': 0.8467907389060031, 'val_acc': 0.8922558922558923}
# index:0,epochs:43
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.524543046951294], 'accuracy': [0.9322351179333583], 'val_loss': [0.3974541425704956], 'val_accuracy': [0.8821548821548821], 'lr': [0.0005]}
# 7/7 [==============================] - 0s 31ms/step
# 7/7 [==============================] - 0s 31ms/step
# UpdateTest:
# {'ACC': 0.9175, 'SP': 0.86, 'SN': 0.975, 'MCC': 0.840576813891019, 'val_acc': 0.8821548821548821}
# index:0,epochs:44
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 42ms/step
# Training:
# {'loss': [0.5255213975906372], 'accuracy': [0.5091725945338824], 'val_loss': [1.01780104637146], 'val_accuracy': [0.48484848484848486], 'lr': [0.0005]}
# index:0,epochs:45
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 42ms/step
# Training:
# {'loss': [0.5184035897254944], 'accuracy': [0.9397229502059153], 'val_loss': [0.43260854482650757], 'val_accuracy': [0.8855218855218855], 'lr': [0.0005]}
# index:0,epochs:46
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 41ms/step
# Training:
# {'loss': [0.527816653251648], 'accuracy': [0.6184949457132161], 'val_loss': [0.757941484451294], 'val_accuracy': [0.6060606060606061], 'lr': [0.0005]}
# index:0,epochs:47
# 84/84 [==============================] - 3s 40ms/step
# 10/10 [==============================] - 0s 39ms/step
# Training:
# {'loss': [0.5235738754272461], 'accuracy': [0.5814301759640584], 'val_loss': [0.7602123618125916], 'val_accuracy': [0.5454545454545454], 'lr': [0.0005]}
# index:0,epochs:48
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.5204071998596191], 'accuracy': [0.9258704605016848], 'val_loss': [0.4337601959705353], 'val_accuracy': [0.8888888888888888], 'lr': [0.0005]}
# index:0,epochs:49
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.5253603458404541], 'accuracy': [0.752527143391988], 'val_loss': [0.5727506279945374], 'val_accuracy': [0.696969696969697], 'lr': [0.0005]}
# index:0,epochs:50
# 84/84 [==============================] - 3s 38ms/step
# 10/10 [==============================] - 0s 41ms/step
# Training:
# {'loss': [0.5272231698036194], 'accuracy': [0.8562336203669038], 'val_loss': [0.5205164551734924], 'val_accuracy': [0.797979797979798], 'lr': [0.0005]}
# index:0,epochs:51
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 32ms/step
# Training:
# {'loss': [0.5265049934387207], 'accuracy': [0.505054286783976], 'val_loss': [1.1820111274719238], 'val_accuracy': [0.48148148148148145], 'lr': [0.0005]}
# index:0,epochs:52
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.5172927379608154], 'accuracy': [0.7641332834144515], 'val_loss': [0.6503815054893494], 'val_accuracy': [0.6835016835016835], 'lr': [0.0005]}
# index:0,epochs:53
# 84/84 [==============================] - 3s 33ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.5214978456497192], 'accuracy': [0.7828528640958442], 'val_loss': [0.5890136361122131], 'val_accuracy': [0.696969696969697], 'lr': [0.0005]}
# index:0,epochs:54
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [0.5170276165008545], 'accuracy': [0.922500935979034], 'val_loss': [0.4567735493183136], 'val_accuracy': [0.8754208754208754], 'lr': [0.0005]}
# index:0,epochs:55
# 84/84 [==============================] - 3s 36ms/step
# 10/10 [==============================] - 0s 32ms/step
# Training:
# {'loss': [0.5161235332489014], 'accuracy': [0.9400973418195433], 'val_loss': [0.38225123286247253], 'val_accuracy': [0.8888888888888888], 'lr': [0.0005]}
# 7/7 [==============================] - 0s 30ms/step
# 7/7 [==============================] - 0s 30ms/step
# UpdateTest:
# {'ACC': 0.9299999999999999, 'SP': 0.92, 'SN': 0.94, 'MCC': 0.8601720516172059, 'val_acc': 0.8888888888888888}
# index:0,epochs:56
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 43ms/step
# Training:
# {'loss': [0.5136333703994751], 'accuracy': [0.8423811306626732], 'val_loss': [0.5387371182441711], 'val_accuracy': [0.7744107744107744], 'lr': [0.0005]}
# index:0,epochs:57
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 1s 50ms/step
# Training:
# {'loss': [0.5135678052902222], 'accuracy': [0.613253463122426], 'val_loss': [0.8044015169143677], 'val_accuracy': [0.5959595959595959], 'lr': [0.0005]}
# index:0,epochs:58
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [0.5102656483650208], 'accuracy': [0.8483713964807188], 'val_loss': [0.5430525541305542], 'val_accuracy': [0.7845117845117845], 'lr': [0.0005]}
# index:0,epochs:59
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.5212899446487427], 'accuracy': [0.6128790715087982], 'val_loss': [0.776220440864563], 'val_accuracy': [0.5791245791245792], 'lr': [0.0005]}
# index:0,epochs:60
# 84/84 [==============================] - 3s 37ms/step
# 10/10 [==============================] - 0s 32ms/step
# Training:
# {'loss': [0.5083480477333069], 'accuracy': [0.8367652564582553], 'val_loss': [0.4958699941635132], 'val_accuracy': [0.7845117845117845], 'lr': [0.0005]}
# index:0,epochs:61
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 42ms/step
# Training:
# {'loss': [0.5126730799674988], 'accuracy': [0.9311119430924747], 'val_loss': [0.38854050636291504], 'val_accuracy': [0.8922558922558923], 'lr': [0.0005]}
# index:0,epochs:62
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 43ms/step
# Training:
# {'loss': [0.515077531337738], 'accuracy': [0.9546986147510296], 'val_loss': [0.38444197177886963], 'val_accuracy': [0.9191919191919192], 'lr': [0.0005]}
# index:0,epochs:63
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 43ms/step
# Training:
# {'loss': [0.5119662880897522], 'accuracy': [0.9266192437289404], 'val_loss': [0.37785977125167847], 'val_accuracy': [0.8888888888888888], 'lr': [0.0005]}
# 7/7 [==============================] - 0s 30ms/step
# 7/7 [==============================] - 0s 31ms/step
# UpdateTest:
# {'ACC': 0.92, 'SP': 0.925, 'SN': 0.915, 'MCC': 0.8400420031502626, 'val_acc': 0.8888888888888888}
# index:0,epochs:64
# 84/84 [==============================] - 3s 36ms/step
# 10/10 [==============================] - 0s 30ms/step
# Training:
# {'loss': [0.5169309973716736], 'accuracy': [0.9086484462748035], 'val_loss': [0.3742654025554657], 'val_accuracy': [0.8585858585858586], 'lr': [0.0005]}
# 7/7 [==============================] - 0s 31ms/step
# 7/7 [==============================] - 0s 30ms/step
# UpdateTest:
# {'ACC': 0.91, 'SP': 0.845, 'SN': 0.975, 'MCC': 0.8270180805175911, 'val_acc': 0.8585858585858586}
# index:0,epochs:65
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.5108822584152222], 'accuracy': [0.5039311119430925], 'val_loss': [1.4883545637130737], 'val_accuracy': [0.48148148148148145], 'lr': [0.0005]}
# index:0,epochs:66
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.5096369385719299], 'accuracy': [0.9198801946836391], 'val_loss': [0.37412968277931213], 'val_accuracy': [0.8888888888888888], 'lr': [0.0005]}
# 7/7 [==============================] - 0s 31ms/step
# 7/7 [==============================] - 0s 30ms/step
# UpdateTest:
# {'ACC': 0.9025, 'SP': 0.865, 'SN': 0.94, 'MCC': 0.8072736590078793, 'val_acc': 0.8888888888888888}
# index:0,epochs:67
# 84/84 [==============================] - 3s 35ms/step
# 10/10 [==============================] - 0s 30ms/step
# Training:
# {'loss': [0.5319717526435852], 'accuracy': [0.5204043429427181], 'val_loss': [1.2634854316711426], 'val_accuracy': [0.48484848484848486], 'lr': [0.0005]}
# index:0,epochs:68
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 40ms/step
# Training:
# {'loss': [0.5127677917480469], 'accuracy': [0.5297641332834144], 'val_loss': [0.7731262445449829], 'val_accuracy': [0.5286195286195287], 'lr': [0.0005]}
# index:0,epochs:69
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [0.5158838629722595], 'accuracy': [0.5791838262822913], 'val_loss': [0.9579957723617554], 'val_accuracy': [0.531986531986532], 'lr': [0.0005]}
# index:0,epochs:70
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 32ms/step
# Training:
# {'loss': [0.5104116201400757], 'accuracy': [0.8611007113440659], 'val_loss': [0.5411549806594849], 'val_accuracy': [0.8047138047138047], 'lr': [0.0005]}
# index:0,epochs:71
# 84/84 [==============================] - 3s 40ms/step
# 10/10 [==============================] - 0s 35ms/step
# Training:
# {'loss': [0.5130624771118164], 'accuracy': [0.9490827405466118], 'val_loss': [0.3416960537433624], 'val_accuracy': [0.9090909090909091], 'lr': [0.0005]}
# 7/7 [==============================] - 0s 32ms/step
# 7/7 [==============================] - 0s 31ms/step
# UpdateTest:
# {'ACC': 0.9275, 'SP': 0.905, 'SN': 0.95, 'MCC': 0.8558670044854914, 'val_acc': 0.9090909090909091}
# index:0,epochs:72
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 32ms/step
# Training:
# {'loss': [0.5099844932556152], 'accuracy': [0.958816922500936], 'val_loss': [0.38329625129699707], 'val_accuracy': [0.9191919191919192], 'lr': [0.0005]}
# index:0,epochs:73
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 32ms/step
# Training:
# {'loss': [0.5104566216468811], 'accuracy': [0.8431299138899289], 'val_loss': [0.5048362612724304], 'val_accuracy': [0.8013468013468014], 'lr': [0.0005]}
# index:0,epochs:74
# 84/84 [==============================] - 3s 41ms/step
# 10/10 [==============================] - 0s 43ms/step
# Training:
# {'loss': [0.5110124945640564], 'accuracy': [0.6510670160988394], 'val_loss': [0.6929336190223694], 'val_accuracy': [0.6531986531986532], 'lr': [0.0005]}
# index:0,epochs:75
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 43ms/step
# Training:
# {'loss': [0.5142903327941895], 'accuracy': [0.9367278172968926], 'val_loss': [0.4376561939716339], 'val_accuracy': [0.8855218855218855], 'lr': [0.0005]}
# index:0,epochs:76
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.5123438835144043], 'accuracy': [0.6289779108947959], 'val_loss': [0.7432867884635925], 'val_accuracy': [0.5723905723905723], 'lr': [0.0005]}
# index:0,epochs:77
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 42ms/step
# Training:
# {'loss': [0.5104854106903076], 'accuracy': [0.6836390864844627], 'val_loss': [0.7676841616630554], 'val_accuracy': [0.6060606060606061], 'lr': [0.0005]}
# index:0,epochs:78
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 32ms/step
# Training:
# {'loss': [0.5085257887840271], 'accuracy': [0.7469112691875702], 'val_loss': [0.6903842091560364], 'val_accuracy': [0.67003367003367], 'lr': [0.0005]}
# index:0,epochs:79
# 84/84 [==============================] - 3s 36ms/step
# 10/10 [==============================] - 0s 43ms/step
# Training:
# {'loss': [0.5102128386497498], 'accuracy': [0.7824784724822164], 'val_loss': [0.5647398829460144], 'val_accuracy': [0.734006734006734], 'lr': [0.0005]}
# index:0,epochs:80
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 1s 50ms/step
# Training:
# {'loss': [0.5022003054618835], 'accuracy': [0.8408835642081617], 'val_loss': [0.4710144102573395], 'val_accuracy': [0.7878787878787878], 'lr': [1e-04]}
# index:0,epochs:81
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 1s 50ms/step
# Training:
# {'loss': [0.5017436146736145], 'accuracy': [0.7596405840509173], 'val_loss': [0.59245365858078], 'val_accuracy': [0.696969696969697], 'lr': [1e-04]}
# index:0,epochs:82
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [0.500617504119873], 'accuracy': [0.8397603893672781], 'val_loss': [0.4695044755935669], 'val_accuracy': [0.7912457912457912], 'lr': [1e-04]}
# index:0,epochs:83
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.4979933500289917], 'accuracy': [0.8910520404342943], 'val_loss': [0.38666146993637085], 'val_accuracy': [0.8451178451178452], 'lr': [1e-04]}
# index:0,epochs:84
# 84/84 [==============================] - 3s 38ms/step
# 10/10 [==============================] - 0s 42ms/step
# Training:
# {'loss': [0.5036428570747375], 'accuracy': [0.7502807937102209], 'val_loss': [0.5646820664405823], 'val_accuracy': [0.7003367003367004], 'lr': [1e-04]}
# index:0,epochs:85
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 1s 55ms/step
# Training:
# {'loss': [0.5044737458229065], 'accuracy': [0.940846125046799], 'val_loss': [0.33698299527168274], 'val_accuracy': [0.9090909090909091], 'lr': [1e-04]}
# 7/7 [==============================] - 0s 32ms/step
# 7/7 [==============================] - 0s 30ms/step
# UpdateTest:
# {'ACC': 0.925, 'SP': 0.885, 'SN': 0.965, 'MCC': 0.8527331260241984, 'val_acc': 0.9090909090909091}
# index:0,epochs:86
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 1s 51ms/step
# Training:
# {'loss': [0.5049744248390198], 'accuracy': [0.9064020965930363], 'val_loss': [0.3649250864982605], 'val_accuracy': [0.8653198653198653], 'lr': [1e-04]}
# index:0,epochs:87
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.5006418228149414], 'accuracy': [0.932983901160614], 'val_loss': [0.3425951898097992], 'val_accuracy': [0.8754208754208754], 'lr': [1e-04]}
# index:0,epochs:88
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.4971209466457367], 'accuracy': [0.948333957319356], 'val_loss': [0.3237106502056122], 'val_accuracy': [0.9225589225589226], 'lr': [1e-04]}
# 7/7 [==============================] - 0s 32ms/step
# 7/7 [==============================] - 0s 31ms/step
# UpdateTest:
# {'ACC': 0.9325, 'SP': 0.895, 'SN': 0.97, 'MCC': 0.8674431242755474, 'val_acc': 0.9225589225589226}
# index:0,epochs:89
# 84/84 [==============================] - 3s 38ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [0.5026823282241821], 'accuracy': [0.956196181205541], 'val_loss': [0.32372480630874634], 'val_accuracy': [0.9225589225589226], 'lr': [1e-04]}
# index:0,epochs:90
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 43ms/step
# Training:
# {'loss': [0.5015658736228943], 'accuracy': [0.953575439910146], 'val_loss': [0.3231796622276306], 'val_accuracy': [0.9158249158249159], 'lr': [1e-04]}
# 7/7 [==============================] - 0s 31ms/step
# 7/7 [==============================] - 0s 31ms/step
# UpdateTest:
# {'ACC': 0.9475, 'SP': 0.925, 'SN': 0.97, 'MCC': 0.8959075660988477, 'val_acc': 0.9158249158249159}
# index:0,epochs:91
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.4977286159992218], 'accuracy': [0.9546986147510296], 'val_loss': [0.3289475739002228], 'val_accuracy': [0.9259259259259259], 'lr': [1e-04]}
# index:0,epochs:92
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 42ms/step
# Training:
# {'loss': [0.49721285700798035], 'accuracy': [0.9183826282291276], 'val_loss': [0.34361135959625244], 'val_accuracy': [0.8619528619528619], 'lr': [1e-04]}
# index:0,epochs:93
# 84/84 [==============================] - 3s 33ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [0.49369099736213684], 'accuracy': [0.9348558592287532], 'val_loss': [0.3197578191757202], 'val_accuracy': [0.8855218855218855], 'lr': [1e-04]}
# 7/7 [==============================] - 0s 31ms/step
# 7/7 [==============================] - 0s 31ms/step
# UpdateTest:
# {'ACC': 0.915, 'SP': 0.85, 'SN': 0.98, 'MCC': 0.8371036668653665, 'val_acc': 0.8855218855218855}
# index:0,epochs:94
# 84/84 [==============================] - 3s 39ms/step
# 10/10 [==============================] - 0s 41ms/step
# Training:
# {'loss': [0.4973609447479248], 'accuracy': [0.9210033695245227], 'val_loss': [0.3416075110435486], 'val_accuracy': [0.8754208754208754], 'lr': [1e-04]}
# index:0,epochs:95
# 84/84 [==============================] - 3s 33ms/step
# 10/10 [==============================] - 0s 46ms/step
# Training:
# {'loss': [0.49345266819000244], 'accuracy': [0.9524522650692624], 'val_loss': [0.31693658232688904], 'val_accuracy': [0.9158249158249159], 'lr': [1e-04]}
# 7/7 [==============================] - 0s 31ms/step
# 7/7 [==============================] - 0s 30ms/step
# UpdateTest:
# {'ACC': 0.9450000000000001, 'SP': 0.92, 'SN': 0.97, 'MCC': 0.8911145902927308, 'val_acc': 0.9158249158249159}
# index:0,epochs:96
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 32ms/step
# Training:
# {'loss': [0.49425971508026123], 'accuracy': [0.9281168101834519], 'val_loss': [0.3295592963695526], 'val_accuracy': [0.8855218855218855], 'lr': [1e-04]}
# index:0,epochs:97
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.49578946828842163], 'accuracy': [0.938225383751404], 'val_loss': [0.3878015875816345], 'val_accuracy': [0.8922558922558923], 'lr': [1e-04]}
# index:0,epochs:98
# 84/84 [==============================] - 3s 40ms/step
# 10/10 [==============================] - 0s 40ms/step
# Training:
# {'loss': [0.5007242560386658], 'accuracy': [0.9685511044552602], 'val_loss': [0.3366765081882477], 'val_accuracy': [0.9393939393939394], 'lr': [1e-04]}
# index:0,epochs:99
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 41ms/step
# Training:
# {'loss': [0.49766629934310913], 'accuracy': [0.9344814676151254], 'val_loss': [0.3258856534957886], 'val_accuracy': [0.8888888888888888], 'lr': [1e-04]}
# index:0,epochs:100
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 42ms/step
# Training:
# {'loss': [0.49348708987236023], 'accuracy': [0.9348558592287532], 'val_loss': [0.32549721002578735], 'val_accuracy': [0.8754208754208754], 'lr': [1e-04]}
# index:0,epochs:101
# 84/84 [==============================] - 3s 36ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.4955487549304962], 'accuracy': [0.8929239985024335], 'val_loss': [0.36715206503868103], 'val_accuracy': [0.8484848484848485], 'lr': [1e-04]}
# index:0,epochs:102
# 84/84 [==============================] - 3s 38ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [0.49562138319015503], 'accuracy': [0.948333957319356], 'val_loss': [0.357416570186615], 'val_accuracy': [0.9124579124579124], 'lr': [1e-04]}
# index:0,epochs:103
# 84/84 [==============================] - 3s 33ms/step
# 10/10 [==============================] - 0s 42ms/step
# Training:
# {'loss': [0.5036932826042175], 'accuracy': [0.8655934107076001], 'val_loss': [0.39990541338920593], 'val_accuracy': [0.8148148148148148], 'lr': [1e-04]}
# index:0,epochs:104
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.49972981214523315], 'accuracy': [0.9116435791838263], 'val_loss': [0.3555421233177185], 'val_accuracy': [0.8552188552188552], 'lr': [1e-04]}
# index:0,epochs:105
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 32ms/step
# Training:
# {'loss': [0.4948658347129822], 'accuracy': [0.9472107824784725], 'val_loss': [0.3221280574798584], 'val_accuracy': [0.9090909090909091], 'lr': [1e-04]}
# index:0,epochs:106
# 84/84 [==============================] - 3s 40ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [0.49633851647377014], 'accuracy': [0.9475851740921003], 'val_loss': [0.31111299991607666], 'val_accuracy': [0.9090909090909091], 'lr': [1e-04]}
# 7/7 [==============================] - 0s 31ms/step
# 7/7 [==============================] - 0s 31ms/step
# UpdateTest:
# {'ACC': 0.93, 'SP': 0.885, 'SN': 0.975, 'MCC': 0.863504303069474, 'val_acc': 0.9090909090909091}
# index:0,epochs:107
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 43ms/step
# Training:
# {'loss': [0.49475714564323425], 'accuracy': [0.9266192437289404], 'val_loss': [0.33458730578422546], 'val_accuracy': [0.8653198653198653], 'lr': [1e-04]}
# index:0,epochs:108
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 32ms/step
# Training:
# {'loss': [0.49658510088920593], 'accuracy': [0.912392362411082], 'val_loss': [0.3475113809108734], 'val_accuracy': [0.8585858585858586], 'lr': [1e-04]}
# index:0,epochs:109
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 43ms/step
# Training:
# {'loss': [0.49185797572135925], 'accuracy': [0.9554473979782853], 'val_loss': [0.3172082006931305], 'val_accuracy': [0.9158249158249159], 'lr': [1e-04]}
# index:0,epochs:110
# 84/84 [==============================] - 3s 41ms/step
# 10/10 [==============================] - 0s 32ms/step
# Training:
# {'loss': [0.4965217411518097], 'accuracy': [0.9371022089105204], 'val_loss': [0.31814974546432495], 'val_accuracy': [0.8821548821548821], 'lr': [1e-04]}
# index:0,epochs:111
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.49611833691596985], 'accuracy': [0.9108947959565705], 'val_loss': [0.34352293610572815], 'val_accuracy': [0.8619528619528619], 'lr': [1e-04]}
# index:0,epochs:112
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.49368521571159363], 'accuracy': [0.948333957319356], 'val_loss': [0.31218570470809937], 'val_accuracy': [0.9124579124579124], 'lr': [1e-04]}
# index:0,epochs:113
# 84/84 [==============================] - 3s 41ms/step
# 10/10 [==============================] - 0s 32ms/step
# Training:
# {'loss': [0.49002954363822937], 'accuracy': [0.9344814676151254], 'val_loss': [0.31876593828201294], 'val_accuracy': [0.8956228956228957], 'lr': [1e-04]}
# index:0,epochs:114
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 43ms/step
# Training:
# {'loss': [0.49673882126808167], 'accuracy': [0.9595657057281917], 'val_loss': [0.3160778880119324], 'val_accuracy': [0.9225589225589226], 'lr': [1e-04]}
# index:0,epochs:115
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 1s 52ms/step
# Training:
# {'loss': [0.5020101070404053], 'accuracy': [0.8940471733433171], 'val_loss': [0.3670385181903839], 'val_accuracy': [0.8451178451178452], 'lr': [1e-04]}
# index:0,epochs:116
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.49717068672180176], 'accuracy': [0.9157618869337327], 'val_loss': [0.3339013159275055], 'val_accuracy': [0.8653198653198653], 'lr': [1e-04]}
# index:0,epochs:117
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 32ms/step
# Training:
# {'loss': [0.4976426064968109], 'accuracy': [0.9120179707974542], 'val_loss': [0.34146609902381897], 'val_accuracy': [0.8585858585858586], 'lr': [1e-04]}
# index:0,epochs:118
# 84/84 [==============================] - 3s 40ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [0.4942018985748291], 'accuracy': [0.9610632721827032], 'val_loss': [0.32952648401260376], 'val_accuracy': [0.9225589225589226], 'lr': [1e-04]}
# index:0,epochs:119
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 45ms/step
# Training:
# {'loss': [0.4931890070438385], 'accuracy': [0.9558217895919131], 'val_loss': [0.3027998208999634], 'val_accuracy': [0.9259259259259259], 'lr': [1e-04]}
# 7/7 [==============================] - 0s 32ms/step
# 7/7 [==============================] - 0s 32ms/step
# UpdateTest:
# {'ACC': 0.9450000000000001, 'SP': 0.91, 'SN': 0.98, 'MCC': 0.8921885461995416, 'val_acc': 0.9259259259259259}
# index:1,epochs:0
# 84/84 [==============================] - 13s 33ms/step
# 10/10 [==============================] - 0s 32ms/step
# Training:
# {'loss': [12.585225105285645], 'accuracy': [0.5001871958068139], 'val_loss': [9.146574974060059], 'val_accuracy': [0.4983164983164983], 'lr': [0.001]}
# 7/7 [==============================] - 0s 31ms/step
# 7/7 [==============================] - 0s 30ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.4983164983164983}
# index:1,epochs:1
# 84/84 [==============================] - 3s 37ms/step
# 10/10 [==============================] - 0s 33ms/step
# Training:
# {'loss': [7.047272682189941], 'accuracy': [0.5001871958068139], 'val_loss': [5.092360973358154], 'val_accuracy': [0.4983164983164983], 'lr': [0.001]}
# 7/7 [==============================] - 0s 31ms/step
# 7/7 [==============================] - 0s 31ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.4983164983164983}
# index:1,epochs:2
# 84/84 [==============================] - 3s 31ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [3.8616044521331787], 'accuracy': [0.5001871958068139], 'val_loss': [2.983557939529419], 'val_accuracy': [0.4983164983164983], 'lr': [0.001]}
# 7/7 [==============================] - 0s 31ms/step
# 7/7 [==============================] - 0s 32ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.4983164983164983}
# index:1,epochs:3
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 42ms/step
# Training:
# {'loss': [2.293968439102173], 'accuracy': [0.5001871958068139], 'val_loss': [1.9393151998519897], 'val_accuracy': [0.4983164983164983], 'lr': [0.001]}
# 7/7 [==============================] - 0s 30ms/step
# 7/7 [==============================] - 0s 33ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.4983164983164983}
# index:1,epochs:4
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 32ms/step
# Training:
# {'loss': [1.4861680269241333], 'accuracy': [0.5001871958068139], 'val_loss': [1.403998613357544], 'val_accuracy': [0.4983164983164983], 'lr': [0.001]}
# 7/7 [==============================] - 0s 41ms/step
# 7/7 [==============================] - 0s 42ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.4983164983164983}
# index:1,epochs:5
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 45ms/step
# Training:
# {'loss': [1.0965067148208618], 'accuracy': [0.5001871958068139], 'val_loss': [1.1296306848526], 'val_accuracy': [0.4983164983164983], 'lr': [0.001]}
# 7/7 [==============================] - 0s 31ms/step
# 7/7 [==============================] - 0s 31ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.4983164983164983}
# index:1,epochs:6
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.8659539818763733], 'accuracy': [0.5001871958068139], 'val_loss': [1.0462596416473389], 'val_accuracy': [0.4983164983164983], 'lr': [0.001]}
# 7/7 [==============================] - 0s 32ms/step
# 7/7 [==============================] - 0s 31ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.4983164983164983}
# index:1,epochs:7
# 84/84 [==============================] - 3s 37ms/step
# 10/10 [==============================] - 0s 45ms/step
# Training:
# {'loss': [0.767368733882904], 'accuracy': [0.5001871958068139], 'val_loss': [0.9298719167709351], 'val_accuracy': [0.4983164983164983], 'lr': [0.001]}
# 7/7 [==============================] - 0s 31ms/step
# 7/7 [==============================] - 0s 31ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.4983164983164983}
# index:1,epochs:8
# 84/84 [==============================] - 3s 41ms/step
# 10/10 [==============================] - 0s 32ms/step
# Training:
# {'loss': [0.690043568611145], 'accuracy': [0.5001871958068139], 'val_loss': [0.8636000752449036], 'val_accuracy': [0.4983164983164983], 'lr': [0.001]}
# 7/7 [==============================] - 0s 32ms/step
# 7/7 [==============================] - 0s 31ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.4983164983164983}
# index:1,epochs:9
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [0.6410853862762451], 'accuracy': [0.5001871958068139], 'val_loss': [0.8442208766937256], 'val_accuracy': [0.4983164983164983], 'lr': [0.001]}
# 7/7 [==============================] - 0s 31ms/step
# 7/7 [==============================] - 0s 31ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.4983164983164983}
# index:1,epochs:10
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 31ms/step
# Training:
# {'loss': [0.6043227910995483], 'accuracy': [0.5001871958068139], 'val_loss': [0.8045855164527893], 'val_accuracy': [0.4983164983164983], 'lr': [0.001]}
# 7/7 [==============================] - 0s 31ms/step
# 7/7 [==============================] - 0s 41ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.4983164983164983}
# index:1,epochs:11
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 33ms/step
# Training:
# {'loss': [0.5948293209075928], 'accuracy': [0.5001871958068139], 'val_loss': [0.838836133480072], 'val_accuracy': [0.4983164983164983], 'lr': [0.001]}
# index:1,epochs:12
# 84/84 [==============================] - 3s 40ms/step
# 10/10 [==============================] - 0s 43ms/step
# Training:
# {'loss': [0.5873294472694397], 'accuracy': [0.5001871958068139], 'val_loss': [0.8179457187652588], 'val_accuracy': [0.4983164983164983], 'lr': [0.001]}
# index:1,epochs:13
# 84/84 [==============================] - 3s 35ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [0.5768777132034302], 'accuracy': [0.5001871958068139], 'val_loss': [0.8478041887283325], 'val_accuracy': [0.4983164983164983], 'lr': [0.001]}
# index:1,epochs:14
# 84/84 [==============================] - 3s 32ms/step
# 10/10 [==============================] - 0s 32ms/step
# Training:
# {'loss': [0.5796192288398743], 'accuracy': [0.6035192811681018], 'val_loss': [0.7228061556816101], 'val_accuracy': [0.4983164983164983], 'lr': [0.001]}
# 7/7 [==============================] - 0s 41ms/step
# 7/7 [==============================] - 0s 45ms/step
# UpdateTest:
# {'ACC': 0.58, 'SP': 1.0, 'SN': 0.16, 'MCC': 0.29488391230979427, 'val_acc': 0.4983164983164983}
# index:1,epochs:15
# 84/84 [==============================] - 3s 32ms/step
# ...
# Training:
# {'loss': [0.49846962094306946], 'accuracy': [0.9524522650692624], 'val_loss': [0.3011382520198822], 'val_accuracy': [0.8888888888888888], 'lr': [1e-04]}
# 7/7 [==============================] - 0s 33ms/step
# 7/7 [==============================] - 0s 33ms/step
# UpdateTest:
# {'ACC': 0.93, 'SP': 0.885, 'SN': 0.975, 'MCC': 0.863504303069474, 'val_acc': 0.8888888888888888}
# index:2,epochs:112
# 84/84 [==============================] - 3s 33ms/step
# 10/10 [==============================] - 0s 34ms/step
# Training:
# {'loss': [0.49205780029296875], 'accuracy': [0.9239985024335455], 'val_loss': [0.32709646224975586], 'val_accuracy': [0.8249158249158249], 'lr': [1e-04]}
# index:2,epochs:113
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 35ms/step
# Training:
# {'loss': [0.4936419129371643], 'accuracy': [0.9427180831149382], 'val_loss': [0.3091977834701538], 'val_accuracy': [0.8518518518518519], 'lr': [1e-04]}
# index:2,epochs:114
# 84/84 [==============================] - 4s 44ms/step
# 10/10 [==============================] - 0s 33ms/step
# Training:
# {'loss': [0.4968709945678711], 'accuracy': [0.9135155372519655], 'val_loss': [0.34749099612236023], 'val_accuracy': [0.8249158249158249], 'lr': [1e-04]}
# index:2,epochs:115
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 33ms/step
# Training:
# {'loss': [0.49630603194236755], 'accuracy': [0.9138899288655934], 'val_loss': [0.3474014699459076], 'val_accuracy': [0.8282828282828283], 'lr': [1e-04]}
# index:2,epochs:116
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [0.49472954869270325], 'accuracy': [0.9138899288655934], 'val_loss': [0.34711092710494995], 'val_accuracy': [0.8215488215488216], 'lr': [1e-04]}
# index:2,epochs:117
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [0.4959530234336853], 'accuracy': [0.9580681392736803], 'val_loss': [0.32207778096199036], 'val_accuracy': [0.9023569023569024], 'lr': [1e-04]}
# index:2,epochs:118
# 84/84 [==============================] - 3s 39ms/step
# 10/10 [==============================] - 0s 34ms/step
# Training:
# {'loss': [0.4980528652667999], 'accuracy': [0.9505803070011232], 'val_loss': [0.3055037558078766], 'val_accuracy': [0.8653198653198653], 'lr': [1e-04]}
# index:2,epochs:119
# 84/84 [==============================] - 3s 35ms/step
# 10/10 [==============================] - 0s 45ms/step
# Training:
# {'loss': [0.49203357100486755], 'accuracy': [0.9363534256832647], 'val_loss': [0.31025776267051697], 'val_accuracy': [0.8417508417508418], 'lr': [1e-04]}
# index:3,epochs:0
# 84/84 [==============================] - 13s 35ms/step
# 10/10 [==============================] - 0s 34ms/step
# Training:
# {'loss': [12.801830291748047], 'accuracy': [0.5046798951703482], 'val_loss': [9.687143325805664], 'val_accuracy': [0.45791245791245794], 'lr': [0.001]}
# 7/7 [==============================] - 0s 33ms/step
# 7/7 [==============================] - 0s 33ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.45791245791245794}
# index:3,epochs:1
# 84/84 [==============================] - 3s 39ms/step
# 10/10 [==============================] - 0s 34ms/step
# Training:
# {'loss': [7.503263473510742], 'accuracy': [0.5046798951703482], 'val_loss': [5.677183151245117], 'val_accuracy': [0.45791245791245794], 'lr': [0.001]}
# 7/7 [==============================] - 0s 33ms/step
# 7/7 [==============================] - 0s 33ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.45791245791245794}
# index:3,epochs:2
# 84/84 [==============================] - 3s 39ms/step
# 10/10 [==============================] - 0s 47ms/step
# Training:
# {'loss': [4.353102684020996], 'accuracy': [0.5552227630101085], 'val_loss': [3.4032464027404785], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# 7/7 [==============================] - 0s 33ms/step
# 7/7 [==============================] - 0s 33ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.5420875420875421}
# index:3,epochs:3
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [2.6331634521484375], 'accuracy': [0.49532010482965183], 'val_loss': [2.2081010341644287], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# 7/7 [==============================] - 0s 33ms/step
# 7/7 [==============================] - 0s 33ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.5420875420875421}
# index:3,epochs:4
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 45ms/step
# Training:
# {'loss': [1.7686718702316284], 'accuracy': [0.5046798951703482], 'val_loss': [1.5944983959197998], 'val_accuracy': [0.45791245791245794], 'lr': [0.001]}
# 7/7 [==============================] - 0s 34ms/step
# 7/7 [==============================] - 0s 33ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.45791245791245794}
# index:3,epochs:5
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 34ms/step
# Training:
# {'loss': [1.2678852081298828], 'accuracy': [0.49532010482965183], 'val_loss': [1.247595191001892], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# 7/7 [==============================] - 0s 47ms/step
# 7/7 [==============================] - 0s 49ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.5420875420875421}
# index:3,epochs:6
# 84/84 [==============================] - 3s 33ms/step
# 10/10 [==============================] - 0s 33ms/step
# Training:
# {'loss': [0.9788988828659058], 'accuracy': [0.49532010482965183], 'val_loss': [1.041184902191162], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# 7/7 [==============================] - 0s 33ms/step
# 7/7 [==============================] - 0s 33ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.5420875420875421}
# index:3,epochs:7
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 33ms/step
# Training:
# {'loss': [0.8390830159187317], 'accuracy': [0.49532010482965183], 'val_loss': [0.9340274930000305], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# 7/7 [==============================] - 0s 33ms/step
# 7/7 [==============================] - 0s 34ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.5420875420875421}
# index:3,epochs:8
# 84/84 [==============================] - 3s 41ms/step
# 10/10 [==============================] - 0s 45ms/step
# Training:
# {'loss': [0.7509966492652893], 'accuracy': [0.49532010482965183], 'val_loss': [0.8522611260414124], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# 7/7 [==============================] - 0s 48ms/step
# 7/7 [==============================] - 0s 33ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.5420875420875421}
# index:3,epochs:9
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 34ms/step
# Training:
# {'loss': [0.6948414444923401], 'accuracy': [0.49532010482965183], 'val_loss': [0.8157039284706116], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# 7/7 [==============================] - 0s 33ms/step
# 7/7 [==============================] - 0s 34ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.5420875420875421}
# index:3,epochs:10
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 34ms/step
# Training:
# {'loss': [0.6717674732208252], 'accuracy': [0.49532010482965183], 'val_loss': [0.7957069873809814], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# 7/7 [==============================] - 0s 33ms/step
# 7/7 [==============================] - 0s 33ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.5420875420875421}
# index:3,epochs:11
# 84/84 [==============================] - 4s 44ms/step
# 10/10 [==============================] - 0s 34ms/step
# Training:
# {'loss': [0.6369661092758179], 'accuracy': [0.49532010482965183], 'val_loss': [0.7677962779998779], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# 7/7 [==============================] - 0s 32ms/step
# 7/7 [==============================] - 0s 32ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.5420875420875421}
# index:3,epochs:12
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 45ms/step
# Training:
# {'loss': [0.6023117303848267], 'accuracy': [0.49532010482965183], 'val_loss': [0.7622578144073486], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# 7/7 [==============================] - 0s 33ms/step
# 7/7 [==============================] - 0s 32ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.5420875420875421}
# index:3,epochs:13
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 1s 55ms/step
# Training:
# {'loss': [0.583591639995575], 'accuracy': [0.9835267690003744], 'val_loss': [0.7082106471061707], 'val_accuracy': [0.9966329966329966], 'lr': [0.001]}
# 7/7 [==============================] - 0s 46ms/step
# 7/7 [==============================] - 0s 37ms/step
# UpdateTest:
# {'ACC': 1.0, 'SP': 1.0, 'SN': 1.0, 'MCC': 1.0, 'val_acc': 0.9966329966329966}
# index:3,epochs:14
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 34ms/step
# Training:
# {'loss': [0.5870634913444519], 'accuracy': [0.49532010482965183], 'val_loss': [0.7303431034088135], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# index:3,epochs:15
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 33ms/step
# Training:
# {'loss': [0.5865660309791565], 'accuracy': [0.49532010482965183], 'val_loss': [0.7183951139450073], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# index:3,epochs:16
# 84/84 [==============================] - 4s 43ms/step
# 10/10 [==============================] - 0s 47ms/step
# Training:
# {'loss': [0.5604871511459351], 'accuracy': [0.5046798951703482], 'val_loss': [0.7211393117904663], 'val_accuracy': [0.45791245791245794], 'lr': [0.001]}
# index:3,epochs:17
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 35ms/step
# Training:
# {'loss': [0.5617704391479492], 'accuracy': [0.49532010482965183], 'val_loss': [0.7419536709785461], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# index:3,epochs:18
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 46ms/step
# Training:
# {'loss': [0.5590049028396606], 'accuracy': [0.49532010482965183], 'val_loss': [0.6942501664161682], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# 7/7 [==============================] - 0s 34ms/step
# 7/7 [==============================] - 0s 33ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.5420875420875421}
# index:3,epochs:19
# 84/84 [==============================] - 3s 41ms/step
# 10/10 [==============================] - 0s 39ms/step
# Training:
# {'loss': [0.5568906664848328], 'accuracy': [0.49532010482965183], 'val_loss': [0.8123430013656616], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# index:3,epochs:20
# 84/84 [==============================] - 3s 39ms/step
# 10/10 [==============================] - 0s 47ms/step
# Training:
# {'loss': [0.562031090259552], 'accuracy': [0.7229502059153875], 'val_loss': [0.6691955327987671], 'val_accuracy': [0.5858585858585859], 'lr': [0.001]}
# 7/7 [==============================] - 0s 32ms/step
# 7/7 [==============================] - 0s 33ms/step
# UpdateTest:
# {'ACC': 0.7, 'SP': 1.0, 'SN': 0.4, 'MCC': 0.5, 'val_acc': 0.5858585858585859}
# index:3,epochs:21
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 39ms/step
# Training:
# {'loss': [0.5609840154647827], 'accuracy': [0.5885436166229876], 'val_loss': [0.6531612277030945], 'val_accuracy': [0.6195286195286195], 'lr': [0.001]}
# 7/7 [==============================] - 0s 47ms/step
# 7/7 [==============================] - 0s 47ms/step
# UpdateTest:
# {'ACC': 0.5675, 'SP': 0.135, 'SN': 1.0, 'MCC': 0.26904657400017795, 'val_acc': 0.6195286195286195}
# index:3,epochs:22
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 47ms/step
# Training:
# {'loss': [0.5357998013496399], 'accuracy': [0.49532010482965183], 'val_loss': [0.8086745738983154], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# index:3,epochs:23
# 84/84 [==============================] - 3s 33ms/step
# 10/10 [==============================] - 0s 46ms/step
# Training:
# {'loss': [0.5402758717536926], 'accuracy': [0.5054286783976039], 'val_loss': [0.6689589023590088], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# index:3,epochs:24
# 84/84 [==============================] - 3s 35ms/step
# 10/10 [==============================] - 0s 46ms/step
# Training:
# {'loss': [0.5407912135124207], 'accuracy': [0.4956944964432797], 'val_loss': [0.6815165281295776], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# index:3,epochs:25
# 84/84 [==============================] - 4s 42ms/step
# 10/10 [==============================] - 0s 33ms/step
# Training:
# {'loss': [0.5407949090003967], 'accuracy': [0.5409958816922501], 'val_loss': [0.684100866317749], 'val_accuracy': [0.4612794612794613], 'lr': [0.001]}
# index:3,epochs:26
# 84/84 [==============================] - 3s 33ms/step
# 10/10 [==============================] - 0s 33ms/step
# Training:
# {'loss': [0.563239574432373], 'accuracy': [0.505054286783976], 'val_loss': [0.7782742381095886], 'val_accuracy': [0.45791245791245794], 'lr': [0.001]}
# index:3,epochs:27
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 46ms/step
# Training:
# {'loss': [0.5464171171188354], 'accuracy': [0.49532010482965183], 'val_loss': [0.9909658432006836], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# index:3,epochs:28
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 33ms/step
# Training:
# {'loss': [0.5390822887420654], 'accuracy': [0.49532010482965183], 'val_loss': [1.0734641551971436], 'val_accuracy': [0.5420875420875421], 'lr': [0.001]}
# index:3,epochs:29
# 84/84 [==============================] - 3s 41ms/step
# 10/10 [==============================] - 0s 44ms/step
# Training:
# {'loss': [0.5470882654190063], 'accuracy': [0.6769000374391614], 'val_loss': [0.6195489764213562], 'val_accuracy': [0.7037037037037037], 'lr': [0.001]}
# 7/7 [==============================] - 0s 32ms/step
# 7/7 [==============================] - 0s 32ms/step
# UpdateTest:
# {'ACC': 0.6275, 'SP': 0.255, 'SN': 1.0, 'MCC': 0.3822718995134132, 'val_acc': 0.7037037037037037}
# index:3,epochs:30
# 84/84 [==============================] - 3s 36ms/step
# 10/10 [==============================] - 0s 46ms/step
# Training:
# {'loss': [0.5412300229072571], 'accuracy': [0.49831523773867464], 'val_loss': [0.9282664060592651], 'val_accuracy': [0.5420875420875421], 'lr': [0.0005]}
# index:3,epochs:31
# 84/84 [==============================] - 3s 33ms/step
# 10/10 [==============================] - 0s 33ms/step
# Training:
# {'loss': [0.5300803184509277], 'accuracy': [0.4971920628977911], 'val_loss': [0.8629133701324463], 'val_accuracy': [0.5420875420875421], 'lr': [0.0005]}
# index:3,epochs:32
# 84/84 [==============================] - 3s 34ms/step
# 10/10 [==============================] - 0s 47ms/step
# Training:
# {'loss': [0.522418737411499], 'accuracy': [0.8828154249344815], 'val_loss': [0.47767433524131775], 'val_accuracy': [0.8518518518518519], 'lr': [0.0005]}
# 7/7 [==============================] - 0s 32ms/step
# 7/7 [==============================] - 0s 33ms/step
# UpdateTest:
# {'ACC': 0.8825000000000001, 'SP': 0.775, 'SN': 0.99, 'MCC': 0.7833186518929555, 'val_acc': 0.8518518518518519}
# index:3,epochs:33

# %% [markdown]
# **benchmark classifier**

# %%
from random import shuffle
from turtle import shape
from numpy import dtype
import tensorflow as tf
from sklearn.model_selection import KFold
import sys
sys.path.append('.')

# %%
def readTxt(file):
    with open(file,'r',encoding="utf-8") as f:
        return f.read().split("\n")

dic={'A':'A','T':'T','G':'G','C':'C'}
dic_con={'A':1,'T':2,'G':3,'C':4}

# %%
def readTxt(file):
    with open(file,'r',encoding="utf-8") as f:
        return f.read().split("\n")
non_test=readTxt("/content/drive/MyDrive/iEnhancer-DLRA/dataset/non_test.txt")
non_train=readTxt("/content/drive/MyDrive/iEnhancer-DLRA/dataset/non_train.txt")

strong_test=readTxt("/content/drive/MyDrive/iEnhancer-DLRA/dataset/strong_test.txt")
strong_train=readTxt("/content/drive/MyDrive/iEnhancer-DLRA/dataset/strong_train.txt")
weak_test=readTxt("/content/drive/MyDrive/iEnhancer-DLRA/dataset/weak_test.txt")
weak_train=readTxt("/content/drive/MyDrive/iEnhancer-DLRA/dataset/weak_train.txt")

# %%
def GenerateFromTextToNumpy(label,train):
    train_con=[]
    train_text=[]
    train_y=[]
    train_text_5=[]
    for i in train:
        t=threeSequecne(i,4)
        train_text.append(np.array(t))

        t=threeSequecne(i,7)
        train_text_5.append(np.array(t))

        con_t=[dic_con[key] for key in i]
        train_con.append(np.array(con_t))

        train_y.append(np.array([label]))
    train_con=np.array(train_con)
    train_text=np.array(train_text)
    train_y=np.array(train_y)
    train_text_5=np.array(train_text_5)
    return (train_con,train_text,train_y,train_text_5)

# %%
non_train_data=GenerateFromTextToNumpy(0,non_train)
strong_train_data=GenerateFromTextToNumpy(1,strong_train)
weak_train_data=GenerateFromTextToNumpy(0,weak_train)
feature_text=np.concatenate((strong_train_data[1],weak_train_data[1]))
train_con=np.concatenate((strong_train_data[0],weak_train_data[0]))[:,:,np.newaxis]


train_text=feature_text
train_text_5=np.concatenate((strong_train_data[3],weak_train_data[3]))
train_y=np.concatenate((strong_train_data[2],weak_train_data[2]))

# %%
def GenerateLayerTwoTestData():
    strong_test_data=GenerateFromTextToNumpy(1,strong_test)
    weak_test_data=GenerateFromTextToNumpy(0,weak_test)
    test_x={"con":np.concatenate((strong_test_data[0],weak_test_data[0]))[:,:,np.newaxis],"text":np.concatenate((strong_test_data[1],weak_test_data[1])),"text_5":np.concatenate((strong_test_data[3],weak_test_data[3]))}
    test_y=np.concatenate((strong_test_data[2],weak_test_data[2]))
    return test_x,test_y

test_x,test_y=GenerateLayerTwoTestData()

# %%
def self_evaluate(x,y):
    res=tf.nn.sigmoid(model.predict(x))
    res=np.array(res)
    res[res>=0.5]=1
    res[res<0.5]=0
    sum=0
    correct=0
    for i,j in zip(res,y):
        sum+=1
        if i==j:
            correct+=1
    return correct/sum

# %%
def load_model():
        global encoder
        kernel_num=32
        input_con=tf.keras.Input(shape=(200,1),name='con')
        y=tf.keras.layers.Conv1D(kernel_num,kernel_size=3,strides=1,padding='same', activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.l2(0.01))(input_con)
        y=tf.keras.layers.Conv1D(kernel_num, kernel_size=3,strides=1, padding='same', activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.l2(0.01))(y)

        block1_output=tf.keras.layers.BatchNormalization()(y)

        y=tf.keras.layers.Conv1D(kernel_num, kernel_size=3,strides=1, padding='same', activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.l2(0.01))(block1_output)
        y=tf.keras.layers.Conv1D(kernel_num, kernel_size=3,strides=1, padding='same', activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.l2(0.01))(y)

        y=tf.keras.layers.BatchNormalization()(y)

        block2_output=tf.keras.layers.add([y,block1_output])

        y=tf.keras.layers.Conv1D(kernel_num, kernel_size=3, padding='same', activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.l2(0.01))(block2_output)
        y=tf.keras.layers.Conv1D(kernel_num, kernel_size=3, padding='same', activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.l2(0.01))(y)
        y=tf.keras.layers.BatchNormalization()(y)

        block3_output=tf.keras.layers.add([y,block2_output])




        y=tf.keras.layers.GlobalAveragePooling1D()(block3_output)
        y=tf.keras.layers.Dense(64,activation='relu')(y)

        input_text=tf.keras.Input(shape=(1,),dtype='string',name="text")
        encoder=tf.keras.layers.TextVectorization(max_tokens=100)
        encoder.adapt(train_text)
        x=encoder(input_text)

        x=tf.keras.layers.Embedding(input_dim=len(encoder.get_vocabulary()),output_dim=64,mask_zero=True)(x)
        x=tf.keras.layers.Attention(name="ATT12")([x,x])
        x=tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,return_sequences=True,name="LSTM12"),name="B11")(x)
        x=tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,name="LSTM21"),name="B12")(x)
        x=tf.keras.layers.Dense(8,activation='relu')(x)

        input_text_5=tf.keras.Input(shape=(1,),dtype='string',name="text_5")
        encoder_5=tf.keras.layers.TextVectorization(max_tokens=100)
        encoder_5.adapt(train_text_5)
        z=encoder_5(input_text_5)

        z=tf.keras.layers.Embedding(input_dim=len(encoder.get_vocabulary()),output_dim=64,mask_zero=True)(z)
        z=tf.keras.layers.Attention(name="ATT1")([z,z])
        z=tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,return_sequences=True,name="LSTM1"),name="B1")(z)
        z=tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,name="LSTM2"),name="B2")(z)
        z=tf.keras.layers.Dense(8,activation='relu')(z)

        #x=tf.keras.layers.add([z,x])

        feature_layer=tf.keras.layers.concatenate([z,y])
        att=tf.keras.layers.Attention()([feature_layer,feature_layer,feature_layer])

        d=tf.keras.layers.Dense(768,activation='relu')(att)
        d=tf.keras.layers.Dropout(0.001)(d)
        output=tf.keras.layers.Dense(1)(d)
        model=tf.keras.Model([input_text,input_con,input_text_5],output)
        base_learning_rate = 0.001
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),metrics=['accuracy'])
        return model

# %%
po_test=test_x.copy()
po_test["con"]=po_test["con"][0:100]
po_test["text"]=po_test["text"][0:100]
po_test["text_5"]=po_test["text"][0:100]
ne_test=test_x.copy()
ne_test["con"]=ne_test["con"][100:200]
ne_test["text"]=ne_test["text"][100:200]
ne_test["text_5"]=ne_test["text_5"][100:200]

# %%
def evaluate(x,y):
    res=model.predict(x)
    t=np.array(tf.nn.sigmoid(res),dtype="float32")
    co=0
    num=y.shape[0]
    for i in range(num):
        if int(t[i][0]+0.5)==y[i]:
            co+=1
    return co/num

# %%
def returnAccuracy2():
    import math
    TP=self_evaluate(po_test,test_y[0:100])
    TN=self_evaluate(ne_test,test_y[100:])
    FP=1-TN
    FN=1-TP
    SN=TP/(TP+FN)
    SP=TN/(TN+FP)
    ACC=(TP+TN)/(TP+TN+FN+FP)
    try:
        MCC=(TP*TN-FP*FN)/math.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
    except:
        MCC=-1
    text={"ACC":ACC,"SP":SP,"SN":SN,"MCC":MCC}
    return text

kf=KFold(n_splits=10,shuffle=True,random_state=5)
t=kf.split(train_text)
index_list=[(i[0],i[1]) for i in t]

# %%
def train(index):
    epochs=130
    acc=0
    loss=100
    text={}
    t_acc=0
    for i in range(epochs):
        if i<50:
            lr=0.001
        elif i<100:
            lr=0.0005
        else:
            lr=0.0001

        def scheduler(epoch):
            return lr
        reduce_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
        print(f"index:{index},epochs:{i}")
        history=model.fit(each_fold_train_x,each_fold_train_y,validation_data=(each_fold_val_x,each_fold_val_y),shuffle=True,epochs=1,batch_size=128,callbacks=[reduce_lr])

        train_acc=self_evaluate(each_fold_train_x,each_fold_train_y)
        log_info=history.history
        val_acc=self_evaluate(each_fold_val_x,each_fold_val_y)
        log_info['val_accuracy']=[val_acc]
        log_info['accuracy']=[train_acc]
        print("Training:")
        print(log_info)
        t=returnAccuracy2()
        if i>=0:
            if (history.history["val_accuracy"][0]>=acc and history.history["val_loss"][0]<=loss) or history.history["accuracy"][0]>=t_acc:
                acc=history.history["val_accuracy"][0]
                loss=history.history["val_loss"][0]
                t_acc=history.history["accuracy"][0]
                text=t
                text["val_acc"]=val_acc
                print("UpdateTest:")
                print(text)
    record.append(text)

# %%
def printFinalResult():
    ACC=0
    SP=0
    SN=0
    MCC=0
    for i in rrecord:
        ACC+=i["ACC"]
        SP+=i["SP"]
        SN+=i["SN"]
        MCC+=i["MCC"]
    ACC/=10
    SP/=10
    SN/=10
    MCC/=10
    text={"ACC":ACC,"SP":SP,"SN":SN,"MCC":MCC}
    print(text)

# %%
if __name__=="__main__":
    record=[]
    for fold in range(0,10):
        fold_order=fold
        (train_index,val_index)=index_list[fold_order]
        each_fold_train_x={"con":train_con[train_index],"text":train_text[train_index],"text_5":train_text_5[train_index]}
        each_fold_train_y=train_y[train_index]
        each_fold_val_x={"con":train_con[val_index],"text":train_text[val_index],"text_5":train_text_5[val_index]}
        each_fold_val_y=train_y[val_index]
        model=load_model()
        train(fold)
    printFinalResult()
# Out:
# index:0,epochs:0
# 11/11 [==============================] - 62s 4s/step - loss: 2.1811 - accuracy: 0.5071 - val_loss: 2.0796 - val_accuracy: 0.5101 - lr: 0.0010
# 42/42 [==============================] - 23s 400ms/step
# 5/5 [==============================] - 2s 337ms/step
# Training:
# {'loss': [2.181053400039673], 'accuracy': [0.501123595505618], 'val_loss': [2.079624652862549], 'val_accuracy': [0.4899328859060403], 'lr': [0.001]}
# 4/4 [==============================] - 2s 442ms/step
# 4/4 [==============================] - 1s 258ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.4899328859060403}
# index:0,epochs:1
# 11/11 [==============================] - 34s 3s/step - loss: 1.9327 - accuracy: 0.5041 - val_loss: 1.8761 - val_accuracy: 0.5101 - lr: 0.0010
# 42/42 [==============================] - 17s 397ms/step
# 5/5 [==============================] - 2s 425ms/step
# Training:
# {'loss': [1.9327157735824585], 'accuracy': [0.501123595505618], 'val_loss': [1.8760961294174194], 'val_accuracy': [0.4899328859060403], 'lr': [0.001]}
# 4/4 [==============================] - 2s 543ms/step
# 4/4 [==============================] - 1s 273ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.4899328859060403}
# index:0,epochs:2
# 11/11 [==============================] - 34s 3s/step - loss: 1.7547 - accuracy: 0.5026 - val_loss: 1.7000 - val_accuracy: 0.5101 - lr: 0.0010
# 42/42 [==============================] - 17s 396ms/step
# 5/5 [==============================] - 3s 576ms/step
# Training:
# {'loss': [1.754656434059143], 'accuracy': [0.501123595505618], 'val_loss': [1.700022578239441], 'val_accuracy': [0.4899328859060403], 'lr': [0.001]}
# 4/4 [==============================] - 1s 275ms/step
# 4/4 [==============================] - 1s 268ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.4899328859060403}
# index:0,epochs:3
# 11/11 [==============================] - 34s 3s/step - loss: 1.5872 - accuracy: 0.5191 - val_loss: 1.5601 - val_accuracy: 0.5101 - lr: 0.0010
# 42/42 [==============================] - 17s 394ms/step
# 5/5 [==============================] - 2s 328ms/step
# Training:
# {'loss': [1.5871978998184204], 'accuracy': [0.501123595505618], 'val_loss': [1.5601425170898438], 'val_accuracy': [0.4899328859060403], 'lr': [0.001]}
# 4/4 [==============================] - 2s 473ms/step
# 4/4 [==============================] - 2s 346ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.4899328859060403}
# index:0,epochs:4
# 11/11 [==============================] - 34s 3s/step - loss: 1.4578 - accuracy: 0.4989 - val_loss: 1.4376 - val_accuracy: 0.5101 - lr: 0.0010
# 42/42 [==============================] - 17s 400ms/step
# 5/5 [==============================] - 2s 324ms/step
# Training:
# {'loss': [1.4577831029891968], 'accuracy': [0.501123595505618], 'val_loss': [1.4376360177993774], 'val_accuracy': [0.4899328859060403], 'lr': [0.001]}
# 4/4 [==============================] - 1s 290ms/step
# 4/4 [==============================] - 1s 274ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.4899328859060403}
# index:0,epochs:5
# 11/11 [==============================] - 37s 3s/step - loss: 1.3374 - accuracy: 0.5131 - val_loss: 1.3395 - val_accuracy: 0.5101 - lr: 0.0010
# 42/42 [==============================] - 17s 400ms/step
# 5/5 [==============================] - 2s 431ms/step
# Training:
# {'loss': [1.3374245166778564], 'accuracy': [0.501123595505618], 'val_loss': [1.3394628763198853], 'val_accuracy': [0.4899328859060403], 'lr': [0.001]}
# 4/4 [==============================] - 1s 283ms/step
# 4/4 [==============================] - 1s 286ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.4899328859060403}
# index:0,epochs:6
# 11/11 [==============================] - 36s 3s/step - loss: 1.2509 - accuracy: 0.4981 - val_loss: 1.2524 - val_accuracy: 0.5101 - lr: 0.0010
# 42/42 [==============================] - 17s 403ms/step
# 5/5 [==============================] - 3s 466ms/step
# Training:
# {'loss': [1.2508864402770996], 'accuracy': [0.501123595505618], 'val_loss': [1.2524226903915405], 'val_accuracy': [0.4899328859060403], 'lr': [0.001]}
# 4/4 [==============================] - 1s 285ms/step
# 4/4 [==============================] - 1s 271ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.4899328859060403}
# index:0,epochs:7
# 11/11 [==============================] - 35s 3s/step - loss: 1.1658 - accuracy: 0.5064 - val_loss: 1.1797 - val_accuracy: 0.5101 - lr: 0.0010
# 42/42 [==============================] - 17s 412ms/step
# 5/5 [==============================] - 3s 564ms/step
# Training:
# {'loss': [1.165790319442749], 'accuracy': [0.501123595505618], 'val_loss': [1.1797480583190918], 'val_accuracy': [0.4899328859060403], 'lr': [0.001]}
# 4/4 [==============================] - 1s 286ms/step
# 4/4 [==============================] - 1s 303ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.4899328859060403}
# index:0,epochs:8
# 11/11 [==============================] - 36s 3s/step - loss: 1.0929 - accuracy: 0.5004 - val_loss: 1.1146 - val_accuracy: 0.5101 - lr: 0.0010
# 42/42 [==============================] - 17s 394ms/step
# 5/5 [==============================] - 2s 321ms/step
# Training:
# {'loss': [1.0928583145141602], 'accuracy': [0.501123595505618], 'val_loss': [1.11456298828125], 'val_accuracy': [0.4899328859060403], 'lr': [0.001]}
# 4/4 [==============================] - 2s 511ms/step
# 4/4 [==============================] - 1s 274ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.4899328859060403}
# index:0,epochs:9
# 11/11 [==============================] - 33s 3s/step - loss: 1.0316 - accuracy: 0.4996 - val_loss: 1.0619 - val_accuracy: 0.5101 - lr: 0.0010
# 42/42 [==============================] - 17s 397ms/step
# 5/5 [==============================] - 3s 546ms/step
# Training:
# {'loss': [1.031623125076294], 'accuracy': [0.501123595505618], 'val_loss': [1.061937928199768], 'val_accuracy': [0.4899328859060403], 'lr': [0.001]}
# 4/4 [==============================] - 2s 453ms/step
# 4/4 [==============================] - 1s 260ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.4899328859060403}
# index:0,epochs:10
# 11/11 [==============================] - 33s 3s/step - loss: 0.9888 - accuracy: 0.5176 - val_loss: 1.0181 - val_accuracy: 0.5101 - lr: 0.0010
# 42/42 [==============================] - 17s 401ms/step
# 5/5 [==============================] - 2s 325ms/step
# Training:
# {'loss': [0.9888147711753845], 'accuracy': [0.501123595505618], 'val_loss': [1.0181200504302979], 'val_accuracy': [0.4899328859060403], 'lr': [0.001]}
# 4/4 [==============================] - 1s 270ms/step
# 4/4 [==============================] - 2s 455ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 0.0, 'SN': 1.0, 'MCC': -1, 'val_acc': 0.4899328859060403}
# index:0,epochs:11
# 11/11 [==============================] - 34s 3s/step - loss: 0.9438 - accuracy: 0.4989 - val_loss: 0.9804 - val_accuracy: 0.5101 - lr: 0.0010
# 42/42 [==============================] - 16s 392ms/step
# 5/5 [==============================] - 2s 334ms/step
# Training:
# {'loss': [0.943780243396759], 'accuracy': [0.49887640449438203], 'val_loss': [0.9804431200027466], 'val_accuracy': [0.5100671140939598], 'lr': [0.001]}
# 4/4 [==============================] - 2s 423ms/step
# 4/4 [==============================] - 2s 379ms/step
# UpdateTest:
# {'ACC': 0.5, 'SP': 1.0, 'SN': 0.0, 'MCC': -1, 'val_acc': 0.5100671140939598}
# index:0,epochs:12
# 11/11 [==============================] - 34s 3s/step - loss: 0.9100 - accuracy: 0.5154 - val_loss: 0.9511 - val_accuracy: 0.5101 - lr: 0.0010
# 42/42 [==============================] - 17s 399ms/step
# 5/5 [==============================] - 2s 331ms/step
# Training:
# {'loss': [0.9099929332733154], 'accuracy': [0.8367041198501872], 'val_loss': [0.9510734677314758], 'val_accuracy': [0.5906040268456376], 'lr': [0.001]}
# 4/4 [==============================] - 1s 272ms/step
# 4/4 [==============================] - 1s 269ms/step
# UpdateTest:
# {'ACC': 0.8400000000000001, 'SP': 1.0, 'SN': 0.68, 'MCC': 0.7177405625652735, 'val_acc': 0.5906040268456376}
# index:0,epochs:13
# 11/11 [==============================] - 36s 3s/step - loss: 0.8829 - accuracy: 0.6225 - val_loss: 0.9268 - val_accuracy: 0.5101 - lr: 0.0010
# 42/42 [==============================] - 17s 398ms/step
# 5/5 [==============================] - 2s 358ms/step
# Training:
# {'loss': [0.8828989863395691], 'accuracy': [0.6187265917602996], 'val_loss': [0.9267786741256714], 'val_accuracy': [0.5100671140939598], 'lr': [0.001]}
# 4/4 [==============================] - 1s 293ms/step
# 4/4 [==============================] - 1s 271ms/step
# index:0,epochs:14
#  5/11 [============>.................] - ETA: 19s - loss: 0.9129 - accuracy: 0.4969
